# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
boxspec = np.load('../anzu/data/spectra_aem_compensated.npy')

# %%
zvec = [3.0,2.0,1.0,0.85,0.7,0.55,0.4,0.25,0.1,0.]

#lakelag_mpi_pk_box40_a1.00_nmesh1400.txt

#Load in one of the new boxes at two different redshifts. 
box = 42

snapvec = 1./(1 + np.array(zvec))

boxarr = np.zeros(shape=(3, 10, 10, 700))

for n, box in enumerate([40, 41, 42]):
    for i, a in enumerate(snapvec):

        boxnew = np.loadtxt('/home/users/kokron/scratch/tinkers_emu_ics/Box%03d/ics/lakelag_mpi_pk_box%d_a%.2f_nmesh1400.txt'%(box,box, a))

        boxarr[n,i] = boxnew[1:11]

#snap6
# boxnew2 = np.loadtxt('/home/users/kokron/scratch/tinkers_emu_ics/Box%03d/ics/lakelag_mpi_pk_box%d_a0.71_nmesh1400.txt'%(box,box))
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-4-77bba7446c6e> in <module>
#      13     for i, a in enumerate(snapvec):
#      14
# ---> 15         boxnew = np.loadtxt('/home/users/kokron/scratch/tinkers_emu_ics/Box%03d/ics/lakelag_mpi_pk_box%d_a%.2f_nmesh1400.txt'%(box,box, a))
#      16
#      17         boxarr[n,i] = boxnew[1:11]
#
# ~/.local/lib/python3.7/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows)
#     979             fname = os_fspath(fname)
#     980         if _is_string_like(fname):
# --> 981             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     982             fencoding = getattr(fh, 'encoding', 'latin1')
#     983             fh = iter(fh)
#
# ...

# %%
for i in range(10):
    plt.loglog(k, boxarr[1,i,4])

# %%
snapvec
# Out:
# array([0.25      , 0.33333333, 0.5       , 0.54054054, 0.58823529,
#        0.64516129, 0.71428571, 0.8       , 0.90909091, 1.        ])

# %%
for i in range(1, 11):
    plt.loglog(k, boxnew[i]/boxnew2[i])

# %%
k = boxnew[0]

c = 2

# plt.loglog(k, boxnew[c+1])
plt.loglog(k, boxnew2[c+1])
plt.loglog(k, boxspec[6][6][c])

# %%
boxspec.shape
# Out:
# (40, 10, 10, 700)
